# %% [markdown]
# A Jupyter notebook for filling out the
# [5conversations](https://isbnsearch.org/isbn/9781909623712) Future Focus Wheel

# %% [markdown]
# Fill out the numbers below.  The left number corresponds to your current feeling, the right number to your "want to be".
#
# Take notes in the Dimensions section on why you have chosen those numbers.

# %%
# %matplotlib inline
from spider import main
import pandas as pd

df = pd.DataFrame({
'group': ['Now', 'Then'],
'purpose/meaning': [1, 10],  
'autonomy/freedom': [2, 5],
'mastery/learning': [1, 10],
'innovation/exploration': [2, 5],  
'collaboration/inclusivity': [1, 10],
'acheivement/recognition': [2, 5],
'wlb/wellbeing': [1, 10],
'advancement/promotion': [2, 5],
'reward/security': [1, 10],
'status/power': [2, 5],
})

main(df)

# %% [markdown]
# # The Dimensions
#
#
# ## purpose/meaning
#
#
#
# ## autonomy/freedom
#
#
# ## mastery/learning
#
#
# ## innovation/exploration
#
#
# ## collaboration/inclusivity
#
#
#
# ## achievement/recognition
#
#
#
# ## work-life balance/wellbeing
#
#
# ## advancement/promotion
#
#
# ## reward/security
#
#
# ## status/power
